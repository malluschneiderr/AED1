# %% [markdown]
# # Recapitulação dos Operadores

# %%
''' / = divisão - // = divisão inteira - * = multiplicação - ** = potencia - sqrt (Squar root) Raiz quadrda '''
# Out:
# ' / = divisão - // = divisão inteira - * = multiplicação - ** = potencia - sqrt (Squar root) Raiz quadrda '

# %%
''' expressão lógica - não tem um valor final, ou é true (verdadeiro) ou false (falso). '''
# Out:
# ' expressão lógica - não tem um valor final, ou é true (verdadeiro) ou false (falso). '

# %% [markdown]
# # calculo da área

# %%
base = float(input("Digite a base:"))
altura = float(input("Digite a altura:"))
area = base * altura 
print("A área do Quadrilatero é:", area)
# Out:
# Digite a base: 4.7
# Digite a altura: 5.2
# A área do Quadrilatero é: 24.44
